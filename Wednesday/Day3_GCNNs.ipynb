# %% [markdown]
# <a href="https://colab.research.google.com/github/NafizIR/Gcollab/blob/I-comse/Wednesday/Day3_GCNNs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#First, make sure the notebook is aware of the workshop data sets
# !git clone https://github.com/icomse/9th_workshop_ml_for_molecules.git
import os
os.chdir('9th_workshop_ml_for_molecules/data')
# Out:
# Cloning into '9th_workshop_ml_for_molecules'...
# remote: Enumerating objects: 246, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 246 (delta 66), reused 39 (delta 35), pack-reused 142 (from 1)
# Receiving objects: 100% (246/246), 29.38 MiB | 34.50 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %%
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for torch-scatter (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.0/210.0 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for torch-sparse (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.1 MB/s eta 0:00:00
#   Building wheel for torch-geometric (pyproject.toml) ... done

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:14
# 🔁 Restarting kernel...

# %%
# !mamba install -c conda-forge rdkit
# Out:
# Looking for: ['rdkit']
#
# [+] 0.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   2%
# conda-forge/noarch     3%[+] 0.3s
# conda-forge/linux-64   8%
# conda-forge/noarch    18%[+] 0.4s
# conda-forge/linux-64  20%
# conda-forge/noarch    45%[+] 0.5s
# conda-forge/linux-64  31%
# conda-forge/noarch    67%[+] 0.6s
# conda-forge/linux-64  40%
# conda-forge/noarch    87%conda-forge/noarch
# [+] 0.7s
# conda-forge/linux-64  54%[+] 0.8s
# conda-forge/linux-64  62%[+] 0.9s
# conda-forge/linux-64  72%[+] 1.0s
# conda-forge/linux-64  79%[+] 1.1s
# conda-forge/linux-64  87%[+] 1.2s
# conda-forge/linux-64  94%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - rdkit
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                          Version  Build                 Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────
#
#   + icu                               75.1  he02047a_0            conda-forge       12MB
#   + libpng                          1.6.47  h943b412_0            conda-forge      289kB
#   + xorg-libice                      1.1.2  hb9d3cd8_0            conda-forge       59kB
#   + libwebp-base                     1.5.0  h851e524_0            conda-forge      430kB
#   + libjpeg-turbo                    3.1.0  hb9d3cd8_0            conda-forge      629kB
#   + kiwisolver                       1.4.7  py311hd18a35c_0       conda-forge       72kB
#   + qhull                           2020.2  h434a139_5            conda-forge      553kB
#   + pthread-stubs                      0.4  hb9d3cd8_1002         conda-forge        8kB
#   + xorg-libxdmcp                    1.1.5  hb9d3cd8_0            conda-forge       20kB
#   + xorg-libxau                     1.0.12  hb9d3cd8_0            conda-forge       15kB
#   + lerc                             4.0.0  h0aef613_1            conda-forge      264kB
#   + libgfortran5                    14.2.0  hf1ad2bd_2            conda-forge        1MB
#   + libbrotlicommon                  1.1.0  hb9d3cd8_2            conda-forge       69kB
#   + unicodedata2                    16.0.0  py311h9ecbd09_0       conda-forge      405kB
#   + libntlm                            1.8  hb9d3cd8_0            conda-forge       33kB
#   + pixman                          0.46.0  h29eaf8c_0            conda-forge      399kB
#   + greenlet                         3.2.1  py311hfdbb021_0       conda-forge      239kB
#   + libdeflate                        1.23  h86f0d12_0            conda-forge       73kB
#   + pcre2                            10.44  hc749103_2            conda-forge      956kB
#   + libboost                        1.86.0  h6c02f8c_3            conda-forge        3MB
#   + libfreetype6                    2.13.3  h48d6fc4_1            conda-forge      380kB
#   + xorg-libsm                       1.2.6  he73a12e_0            conda-forge       28kB
#   + libxcb                          1.17.0  h8a09558_0            conda-forge      396kB
#   + libgfortran                     14.2.0  h69a702a_2            conda-forge       54kB
#   + libbrotlienc                     1.1.0  hb9d3cd8_2            conda-forge      282kB
#   + libbrotlidec                     1.1.0  hb9d3cd8_2            conda-forge       33kB
#   + libtiff                          4.7.0  hd9ff511_3            conda-forge      428kB
#   + libglib                         2.82.2  h2ff4ddf_1            conda-forge        4MB
#   + libfreetype                     2.13.3  ha770c72_1            conda-forge        8kB
#   + xorg-libx11                     1.8.12  h4f16b4b_0            conda-forge      836kB
#   + libopenblas                     0.3.29  pthreads_h94d23a6_0   conda-forge        6MB
#   + brotli-bin                       1.1.0  hb9d3cd8_2            conda-forge       19kB
#   + lcms2                             2.17  h717163a_0            conda-forge      248kB
#   + openjpeg                         2.5.3  h5fbd93e_0            conda-forge      343kB
#   + freetype                        2.13.3  ha770c72_1            conda-forge      172kB
#   + xorg-libxrender                 0.9.12  hb9d3cd8_0            conda-forge       33kB
#   + xorg-libxext                     1.3.6  hb9d3cd8_0            conda-forge       50kB
#   + libblas                          3.9.0  31_h59b9bed_openblas  conda-forge       17kB
#   + brotli                           1.1.0  hb9d3cd8_2            conda-forge       19kB
#   + pillow                          11.1.0  py311h1322bbf_0       conda-forge       42MB
#   + fontconfig                      2.15.0  h7e30c49_1            conda-forge      266kB
#   + libcblas                         3.9.0  31_he106b2a_openblas  conda-forge       17kB
#   + liblapack                        3.9.0  31_h7ac8fdf_openblas  conda-forge       17kB
#   + numpy                            2.2.5  py311h5d046bc_0       conda-forge        9MB
#   + contourpy                        1.3.2  py311hd18a35c_0       conda-forge      278kB
#   + libboost-python                 1.86.0  py311h5b7b71f_3       conda-forge      121kB
#   + font-ttf-dejavu-sans-mono         2.37  hab24e00_0            conda-forge      397kB
#   + font-ttf-inconsolata             3.000  h77eed37_0            conda-forge       97kB
#   + font-ttf-source-code-pro         2.038  h77eed37_0            conda-forge      701kB
#   + font-ttf-ubuntu                   0.83  h77eed37_3            conda-forge        2MB
#   + pytz                            2025.2  pyhd8ed1ab_0          conda-forge      189kB
#   + python-tzdata                   2025.2  pyhd8ed1ab_0          conda-forge      144kB
#   + cycler                          0.12.1  pyhd8ed1ab_1          conda-forge       13kB
#   + pyparsing                        3.2.3  pyhd8ed1ab_1          conda-forge       96kB
#   + munkres                          1.1.4  pyh9f0ad1d_0          conda-forge       12kB
#   + six                             1.17.0  pyhd8ed1ab_0          conda-forge       16kB
#   + typing_extensions               4.13.2  pyh29332c3_0          conda-forge       52kB
#   + chardet                          5.2.0  pyhd8ed1ab_3          conda-forge      132kB
#   + freetype-py                      2.3.0  pyhd8ed1ab_0          conda-forge       59kB
#   + fonts-conda-forge                    1  0                     conda-forge        4kB
#   + python-dateutil            2.9.0.post0  pyhff2d567_1          conda-forge      223kB
#   + typing-extensions               4.13.2  h0e9735f_0            conda-forge       90kB
#   + fonts-conda-ecosystem                1  0                     conda-forge        4kB
#   + fonttools                       4.57.0  py311h2dc5d0c_0       conda-forge        3MB
#   + pandas                           2.2.3  py311h7db5c69_3       conda-forge       16MB
#   + sqlalchemy                      2.0.40  py311h9ecbd09_0       conda-forge        4MB
#   + cairo                           1.18.4  h3394656_0            conda-forge      978kB
#   + cyrus-sasl                      2.1.27  h54b06d7_7            conda-forge      220kB
#   + matplotlib-base                 3.10.1  py311h2b939e6_0       conda-forge        8MB
#   + pycairo                         1.27.0  py311h124c5f0_0       conda-forge      116kB
#   + librdkit                     2025.03.2  h84b0b3c_0            conda-forge        9MB
#   + openldap                         2.6.9  he970967_0            conda-forge      784kB
#   + libpq                             17.4  h27ae623_1            conda-forge        3MB
#   + rlpycairo                        0.2.0  pyhd8ed1ab_0          conda-forge       15kB
#   + reportlab                        4.4.0  py311h9ecbd09_0       conda-forge        3MB
#   + rdkit                        2025.03.2  py311h4bf1da0_0       conda-forge       20MB
#
#   Change:
# ──────────────────────────────────────────────────────────────────────────────────────────
#
#   - libxml2                         2.13.5  h0d44e9d_1            conda-forge     Cached
#   + libxml2                         2.13.5  h8d12d68_1            conda-forge      691kB
#
#   Upgrade:
# ──────────────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates             2024.12.14  hbcca054_0            conda-forge     Cached
#   + ca-certificates              2025.4.26  hbd8a1cb_0            conda-forge      152kB
#   - certifi                     2024.12.14  pyhd8ed1ab_0          conda-forge     Cached
#   + certifi                      2025.1.31  pyhd8ed1ab_0          conda-forge      163kB
#   - openssl                          3.4.0  h7b32b05_1            conda-forge     Cached
#   + openssl                          3.5.0  h7b32b05_0            conda-forge        3MB
#
#   Summary:
#
#   Install: 76 packages
#   Change: 1 packages
#   Upgrade: 3 packages
#
#   Total download: 162MB
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%xorg-libice                                         58.6kB @ 613.7kB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (1)  ⣾  libpng                                             288.7kB @   2.2MB/s  0.1s
# libwebp-base                                       430.0kB @   2.9MB/s  0.2s
# libjpeg-turbo                                      628.9kB @   3.9MB/s  0.2s
# kiwisolver                                          72.4kB @ 446.3kB/s  0.1s
# xorg-libxdmcp                                       19.9kB @ 117.2kB/s  0.0s
# [+] 0.2s
# Downloading  (5)   4%
# Extracting   (4)  ⣾  libntlm                                             33.4kB @ 154.6kB/s  0.1s
# libxml2                                            690.6kB @   3.1MB/s  0.1s
# libgfortran5                                         1.5MB @   6.4MB/s  0.1s
# pixman                                             398.7kB @   1.8MB/s  0.1s
# libbrotlidec                                        32.7kB @ 127.0kB/s  0.0s
# libfreetype                                          7.7kB @  28.0kB/s  0.0s
# brotli-bin                                          18.9kB @  68.7kB/s  0.0s
# libxcb                                             395.9kB @   1.4MB/s  0.1s
# freetype                                           172.4kB @ 578.9kB/s  0.0s
# [+] 0.3s
# Downloading  (5)   9%
# Extracting  (10)  ⣾  libblas                                             16.9kB @  54.2kB/s  0.0s
# libcblas                                            16.8kB @  53.8kB/s  0.0s
# brotli                                              19.3kB @  60.8kB/s  0.0s
# font-ttf-dejavu-sans-mono                          397.4kB @   1.2MB/s  0.0s
# font-ttf-inconsolata                                96.5kB @ 269.7kB/s  0.0s
# pytz                                               189.0kB @ 526.8kB/s  0.0s
# pyparsing                                           96.0kB @ 266.5kB/s  0.0s
# typing_extensions                                   52.2kB @ 136.6kB/s  0.0s
# [+] 0.4s
# Downloading  (5)   9%
# Extracting  (16)  ⣾  fonts-conda-forge                                    4.1kB @  10.1kB/s  0.0s
# python-dateutil                                    222.5kB @ 546.1kB/s  0.0s
# cyrus-sasl                                         219.5kB @ 515.2kB/s  0.0s
# openldap                                           784.5kB @   1.6MB/s  0.1s
# qhull                                              552.9kB @   1.2MB/s  0.1s
# [+] 0.5s
# Downloading  (5)  14%
# Extracting  (18)  ⣾  lerc                                               264.2kB @ 510.7kB/s  0.0s
# greenlet                                           239.0kB @ 460.8kB/s  0.0s
# librdkit                                             9.3MB @  16.6MB/s  0.2s
# libfreetype6                                       380.1kB @ 667.9kB/s  0.1s
# pandas                                              15.7MB @  26.5MB/s  0.2s
# [+] 0.6s
# Downloading  (5)  27%
# Extracting  (21)  ⣾  libboost                                             2.9MB @   4.8MB/s  0.1s
# lcms2                                              248.0kB @ 400.7kB/s  0.1s
# xorg-libxext                                        50.1kB @  78.7kB/s  0.0s
# libglib                                              3.9MB @   6.0MB/s  0.1s
# libboost-python                                    121.0kB @ 184.4kB/s  0.0s
# liblapack                                           16.8kB @  25.2kB/s  0.1s
# [+] 0.7s
# Downloading  (5)  31%
# Extracting  (26)  ⣾  cycler                                              13.4kB @  19.0kB/s  0.1s
# chardet                                            132.2kB @ 187.8kB/s  0.0s
# fonts-conda-ecosystem                                3.7kB @   5.2kB/s  0.0s
# font-ttf-source-code-pro                           700.8kB @ 985.9kB/s  0.1s
# pthread-stubs                                        8.3kB @  10.9kB/s  0.0s
# cairo                                              978.1kB @   1.3MB/s  0.1s
# [+] 0.8s
# Downloading  (5)  35%
# Extracting  (30)  ⣾  sqlalchemy                                           3.6MB @   4.5MB/s  0.1s
# libpq                                                2.7MB @   3.4MB/s  0.1s
# libdeflate                                          72.8kB @  90.2kB/s  0.0s
# libgfortran                                         53.7kB @  65.3kB/s  0.0s
# xorg-libxrender                                     33.0kB @  38.4kB/s  0.1s
# xorg-libx11                                        835.9kB @ 964.8kB/s  0.1s
# certifi                                            162.7kB @ 183.8kB/s  0.1s
# [+] 0.9s
# Downloading  (5)  37%
# Extracting  (35)  ⣾  munkres                                             12.5kB @  13.7kB/s  0.1s
# typing-extensions                                   89.9kB @  98.6kB/s  0.0s
# numpy                                                9.1MB @   9.7MB/s  0.1s
# reportlab                                            2.8MB @   2.9MB/s  0.1s
# xorg-libsm                                          27.6kB @  28.1kB/s  0.1s
# matplotlib-base                                      8.4MB @   8.5MB/s  0.1s
# [+] 1.0s
# Downloading  (5)  50%
# Extracting  (38)  ⣾  openjpeg                                           343.0kB @ 331.6kB/s  0.1s
# font-ttf-ubuntu                                      1.6MB @   1.5MB/s  0.1s
# freetype-py                                         58.9kB @  54.8kB/s  0.0s
# [+] 1.1s
# Downloading  (5)  56%
# Extracting  (42)  ⣾  libopenblas                                          5.9MB @   5.4MB/s  0.1s
# pycairo                                            116.3kB @ 102.9kB/s  0.1s
# libbrotlicommon                                     68.9kB @  60.8kB/s  0.1s
# libbrotlienc                                       281.8kB @ 245.0kB/s  0.1s
# fontconfig                                         265.6kB @ 224.9kB/s  0.0s
# [+] 1.2s
# Downloading  (6)  61%
# Extracting  (47)  ⣾  contourpy                                          278.4kB @ 233.3kB/s  0.1s
# unicodedata2                                       405.0kB @ 328.2kB/s  0.1s
# fonttools                                            2.9MB @   2.4MB/s  0.1s
# six                                                 16.4kB @  12.8kB/s  0.0s
# xorg-libxau                                         14.8kB @  11.5kB/s  0.0s
# [+] 1.3s
# Downloading  (5)  67%
# Extracting  (52)  ⣾  ca-certificates                                    152.3kB @ 114.8kB/s  0.1s
# rlpycairo                                           14.9kB @  11.3kB/s  0.0s
# rdkit                                               20.1MB @  15.1MB/s  0.4s
# python-tzdata                                      144.2kB @ 104.6kB/s  0.1s
# [+] 1.4s
# Downloading  (5)  76%
# Extracting  (56)  ⣾  pcre2                                              956.2kB @ 682.1kB/s  0.1s
# openssl                                              3.1MB @   2.2MB/s  0.1s
# libtiff                                            428.2kB @ 300.1kB/s  0.0s
# [+] 1.5s
# Downloading  (2)  84%
# Extracting  (58)  ⣾  [+] 1.6s
# Downloading  (2)  91%
# Extracting  (57)  ⣾  pillow                                              42.0MB @  24.8MB/s  0.5s
# [+] 1.7s
# Downloading  (1)  99%
# Extracting  (55)  ⣾  [+] 1.8s
# Downloading  (1)  99%
# Extracting  (54)  ⣾  [+] 1.9s
# Downloading  (1)  99%
# Extracting  (52)  ⣾  [+] 2.0s
# Downloading  (1)  99%
# Extracting  (50)  ⣾  icu                                                 12.1MB @   6.0MB/s  2.0s
# [+] 2.1s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 2.2s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 2.3s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 2.4s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting  (43)  ⣾  [+] 2.8s
# Downloading      100%
# Extracting  (40)  ⣾  [+] 2.9s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 3.0s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3.1s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3.2s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3.3s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3.4s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3.5s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3.6s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3.7s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3.8s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3.9s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.0s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.1s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.2s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting  (30)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting   (2)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
from rdkit import Chem

import torch

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## Some Useful Functions:

# %%
# I usually keep these in a utils.py file and import them into my other files:
def smiles2geodata(smi,y, feat_dict):
    """
    Inputs:
    smi = smiles string
    y = target
    feat_dict = dictionary where keys are atoms and values are feature array (constructed using get_atom_features function)

    Outputs:
    geo_dp = pytorch geometric datapoint object
    """
    mol = Chem.MolFromSmiles(smi)
    atomic_nums = [atom.GetAtomicNum() for atom in mol.GetAtoms()]
    atom_features = torch.tensor([feat_dict[x] for x in atomic_nums]).float()
    edges = get_edge_indices(mol)
    geo_dp = Data(x=atom_features, edge_index=edges,y=y)

    return geo_dp


def get_edge_indices(mol):
    """
    Inputs:
    mol = rdkit molecule object

    Outputs:
    torch tensor containing edge list (for inputting into smiles2geodata)
    """

    edges =[]
    for bond in mol.GetBonds():
        edges.append((bond.GetBeginAtomIdx(),bond.GetEndAtomIdx()))

    edges = [[x[0] for x in edges],[x[1] for x in edges]]

    return torch.tensor(edges,dtype=torch.long)


def get_atom_features(smi_list):
    """
    One-hot encodes atom types and constructs a dictionary to convert atom types into feature vectors

    Inputs:
    smi_list = list of all smiles in the dataset

    Outputs:
    feat_dict = dictionary where keys are atoms and values are feature array
    """

    atom_types = []
    for smi in smi_list:
        mol = Chem.MolFromSmiles(smi)
        atom_types.extend([atom.GetAtomicNum() for atom in mol.GetAtoms()])

    atom_set = list(set(atom_types))

    enc = OneHotEncoder()
    enc.fit(np.array(atom_set).reshape(-1,1))
    feat_dict = {x:enc.transform([[x]]).toarray()[0] for x in atom_set}

    return feat_dict

# %% [markdown]
# ### Building a deep learning model in Pytorch requires building multiple objects and routines:
#
# 1. <u>Dataset</u>- object that contains your training/validation data
#
# 2. <u>Model</u>- object that contains your model architecture and weights
#
# 3. <u>Train Routine</u>- function that passes training data through model and updates weights
#
# 4. <u>Validation Routine</u>- function that passes validation through model and reports performance

# %% [markdown]
# ## 1. Dataset

# %%
data_path = 'aqsol.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#                                               SMILES  Solubility
# 0                [Br-].CCCCCCCCCCCCCCCCCC[N+](C)(C)C   -3.616127
# 1                               O=C1Nc2cccc3cccc1c23   -3.254767
# 2                                    Clc1ccc(C=O)cc1   -2.177078
# 3  [Zn++].CC(c1ccccc1)c2cc(C(C)c3ccccc3)c(O)c(c2)...   -3.924409
# 4  C1OC1CN(CC2CO2)c3ccc(Cc4ccc(cc4)N(CC5CO5)CC6CO...   -4.662065

# %%
from torch_geometric.data import InMemoryDataset
from torch_geometric.data import Data

# %%
class GeoDataset(InMemoryDataset):
    def __init__(self, root='./',raw_name=data_path,processed_name='lipo_processed.pt',transform=None, pre_transform=None):

        self.filename = os.path.join(root,raw_name)
        # self.processed_filename = os.path.join(root,processed_name)

        # read a csv from that path:
        self.df = pd.read_csv(self.filename)

        # assign dataset attribute "input_vectors" to be the 2048 bit vector representing each molecule:
        self.x = self.df[self.df.columns[0]].values

        # assign dataset attribute "output_targets" to be the scalar representing binding strength (last column):
        self.y = self.df[self.df.columns[-1]].values


        super(GeoDataset, self).__init__(root, transform, pre_transform)

        self.data, self.slices = torch.load(self.processed_paths[0],weights_only=False)


    def processed_file_names(self):
        return ['data.pt']

    def process(self):

        feat_dict = get_atom_features(self.x)

        data_list = [smiles2geodata(x,y,feat_dict) for x,y in zip(self.x,self.y)]

        data, slices = self.collate(data_list)

        torch.save((data, slices), self.processed_paths[0])

# %% [markdown]
# ## 2. Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import aggr

# %%
class GCN_Geo(torch.nn.Module):

    def __init__(self, hidden_dim_gcn=256, hidden_dim_fcn=256):
        super(GCN_Geo, self).__init__()

        self.conv1 = GCNConv(12, hidden_dim_gcn)
        self.conv2 = GCNConv(hidden_dim_gcn, hidden_dim_gcn)

        self.readout = aggr.SumAggregation()

        self.linear1 = nn.Linear(hidden_dim_gcn, hidden_dim_fcn)
        self.linear2 = nn.Linear(hidden_dim_fcn, 1)

    def forward(self, data):

        # Message passing layers:
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)

        # Aggregate to get molecule level features:
        x= self.readout(x,data.batch)

        # FCNN to predict molecular property:
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)

        return x.view(-1,)

# %% [markdown]
# ## Pulling it all together

# %%
from torch_geometric.loader import DataLoader

# %%
device = torch.device('cpu')
model = GCN_Geo().to(device)

dataset = GeoDataset()
dataloader = DataLoader(dataset,batch_size=32,shuffle=True)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
loss_fn = torch.nn.MSELoss()

# %%
model.train()
for epoch in range(30):
    print('Epoch: {}'.format(epoch))
    for batch in dataloader:

        optimizer.zero_grad()

        out = model(batch)

        loss = loss_fn(out.double(), batch.y.double())

        loss.backward()

        optimizer.step()

# %%
def predict(model, dataloader):

    # Set our model to evaluation mode:
    model.eval()

    X_all = []
    y_all = []
    pred_all = []

    # Remove gradients:
    with torch.no_grad():

        # Looping over the dataloader allows us to pull out or input/output data:
        for batch in dataloader:

            # Make a prediction:
            pred = model(batch)

            X_all.append(batch.x)
            y_all.append(batch.y)
            pred_all.append(pred)

    X_all = torch.concat(X_all)
    y_all = torch.concat(y_all)
    pred_all = torch.concat(pred_all)

    return X_all, y_all, pred_all

# %%
x,y,pred = predict(model,dataloader)

# %%
plt.figure(figsize=(4,4))
plt.scatter(y,pred,alpha=0.4)
plt.plot([-1,4],[-1,4],color='k')
plt.show()

# %%
r2_score(y,pred)

# %% [markdown]
# ***HACKING:*** We didn't include training/validation splits! Can you go back and including training and validation splits, using the FCNN code from the previous section as a reference?
